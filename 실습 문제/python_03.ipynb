# %% [markdown]
# #**연산자**

# %% [markdown]
# ## 1. 사용자로부터 하나의 정수를 입력 받아 0 초과 100 미만의 짝수인지를 판단하는 프로그램을 작성하시오.
# ---
# 실행 결과 1
# ```
# 정수: 40
# 입력된 정수는 0에서 100 사이에 있는 짝수입니다: True
# ```
# 실행 결과 2
# ```
# 정수: -40
# 입력된 정수는 0에서 100 사이에 있는 짝수입니다: False
# ```
#
# 실행 결과 3
# ```
# 정수: 35
# 입력된 정수는 0에서 100 사이에 있는 짝수입니다: False
# ```

# %% [markdown]
# ## 2. 세 자리 정수를 입력 받아 역순으로 출력하는 프로그램을 작성하시오.
# ---
# 실행 결과
# ```
# 세 자리 정수를 입력하세요: 591
#
# 1의 자리: 1
# 10의 자리: 9
# 100의 자리: 5
#
# ------
#
# 195
# ```

# %% [markdown]
# #**조건문**

# %% [markdown]
# ##1. 사용자로부터 나이를 입력받아 20세 미만이면 청소년 할인을 해주는 놀이 공원 입장 프로그램을 작성하시오.
#
# ---
# 실행 결과 1
# ```
# 나이: 21
# 입장하세요.
# ```
#
#
# 실행 결과 2
# ```
# 나이: 15
# 청소년 할인되었습니다.
# 입장하세요.
# ```

# %% [markdown]
# ##2. 1000보 이상이면 '목표 달성'을 출력하는 프로그램을 작성하시오.
#
# ---
# 실행 결과 1
# ```
# 걸음 수: 51
# ```
#
#
# 실행 결과 2
# ```
# 걸음 수: 1000
# 목표 달성
# ```

# %% [markdown]
# ##3. 시간을 입력 받아 12시 전이라면 '오전', 12시 이후라면 '오후'를 출력하는 프로그램을 작성하시오.
#
#
# ---
# 실행 결과 1
# ```
# 시간: 10
# 오전입니다.
# ```
#
#
# 실행 결과 2
# ```
# 시간: 23
# 오후입니다.
# ```

# %% [markdown]
# ##4. 속도를 입력 받아 100km/h 이상이면 '고속', 60km/h 이상 100km/h 미만이면 '중속', 60km/h 미만이면 '저속'을 출력하는 프로그램을 작성하시오.
#
#  - 단, 속도가 150 이상이거나, 음수인 경우 오류 메시지를 출력할 것.
#
#
#  ---
#  실행 결과
#  ```
#  속도: -34.7
#  [입력오류] 속도는 0 이상 150 미만의 값만 가능합니다.
#  ```
#
#  실행 결과
#  ```
#  속도: 56.7
#  저속
#  ```

# %% [markdown]
# ##5. 점수를 입력받아 점수에 따라 아래와 같이 등급을 출력하는 프로그램을 작성하시오.
#
#  - 단, 점수가 음수이거나, 100을 초과하는 경우 오류 메시지를 출력할 것.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 6. 나이가 19세 이상이고 키가 150cm 이상이면 탈 수 있는 놀이기구가 있다. 다음과 같이 사용자로부터 나이와 키를 입력받아 이 놀이기구에 탈 수 있는지 없는지를 판단하여 출력하는 프로그램을 작성하시오.
# ---
# 실행 결과
# ```
# 나이를 입력하시오 : 23
# 키를 입력하시오(단위 cm) : 160
# 입장할 수 있습니다.
# ```
# 실행 결과
# ```
# 나이를 입력하시오 : 16
# 키를 입력하시오(단위 cm) : 162
# 입장할 수 없습니다.
# ```

# %% [markdown]
# ## 7. 사용자로부터 알파벳 문자 하나를 입력 받아서 a, e, i, o, u일 경우 ‘모음입니다’를 이 외의 문자일 경우 ‘자음입니다’를 출력하시오.
# ---
#
# 실행 결과 1
# ```
# 알파벳을 입력하시오 :  i
# i (은)는 모음입니다.
# ```
#
#
# 실행 결과 2
# ```
# 알파벳을 입력하시오 :  t
# t (은)는 자음입니다.
# ```

# %% [markdown]
# ##8. 입력한 달에 존재하는 날의 수를 출력하는 프로그램을 작성하시오.
#
# *   4, 6, 9, 11월은 30일까지, 2월은 윤년인 경우 29일, 평년인 경우 28일까지, 그 외의 달은 31일까지 존재한다.
# *   년도가 4의 배수이지만 100의 배수는 아니거나, 400의 배수인 경우 윤년이다.
#
#
#
#
# ---
# 실행 결과 1
# ```
# 년도, 월 (콤마로 구분하여 입력): 2026, 3
# 2026년 3월은 31일까지 존재합니다.
# ```
# 실행 결과 2
# ```
# 년도, 월 (콤마로 구분하여 입력): 2026, 2
# 2026년 2월은 28일까지 존재합니다.
# ```
# 실행 결과 3
# ```
# 년도, 월 (콤마로 구분하여 입력): 2026, 14
# [입력 오류]1월 ~ 12월만 존재합니다.
# ```

# %% [markdown]
# ## 9. 사용자로부터 문자 하나를 입력 받아, 숫자, 알파벳 모음, 자음, 기타문자로 분류하는 프로그램을 작성하시오.
# ---
# 실행 결과 1
# ```
# 문자: A
# A는 모음입니다.
# ```
# 실행 결과 2
# ```
# 문자: b
# b는 자음입니다.
# ```
# 실행 결과 3
# ```
# 문자: 9
# 9는 숫자입니다.
# ```
# 실행 결과 4
# ```
# 문자: +
# +는 기타문자입니다.
# ```
