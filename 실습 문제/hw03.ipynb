# %% [markdown]
# # **교재 문제**

# %% [markdown]
# ## 3.1 다음 조건의 실행 결과는 무엇인가? True 혹은 False로 나타내어라.
# ---
#
# (1) `100>200`
#
# (2) `100>=200`
#
# (3) `100<200`
#
# (4) `100<=200`
#
# (5) `100==200`
#
# (6) `100!=200`
#
# (7) `200==200`
#
# (8) `200!=200`
#
# (9) `True or True`
#
# (10) `True or False`
#
# (11) `True and False`
#
# (12) `True and True`
#
# (13) `True or True and False`
#
# (14) `True and True or False`
#
# (15) `'Morning'<'morning'`
#
# (16) `'A'>'B'`

# %% [markdown]
# ## 3.6 다음과 같이 사용자로부터 3개의 임의의 정수를 입력으로 받아서 가장 작은 수부터 큰 수까지 나열하는 프로그램을 if-else문을 사용하여 작성하시오.
#
# - built-in function  사용 금지
#
# ---
# 실행 결과
#
#
# ```
# 세 정수를 입력하시오 : 9 12 4
# 4 9 12
# ```
# 실행 결과
# ```
# 세 정수를 입력하시오 : 99 12 4
# 4 12 99
# ```

# %% [markdown]
# ## 3.8 사용자로부터 x, y 좌표를 가진 한 점을 입력으로 받아서 이 점이 1,2,3,4 분면의 어디에 속하는지를 알려주는 프로그램을 작성하시오. 사분면의 위치는 다음 그림과 같다.
# ---
# 실행 결과
#
#
# ```
# 점의 좌표 x, y를 입력하시오 : 2.5 4.3
# 1사분면
# ```
# 실행 결과
#
#
# ```
# 점의 좌표 x, y를 입력하시오 : -2.2 -4
# 3사분면
# ```
#
# 실행 결과
#
# ```
# 점의 좌표 x, y를 입력하시오 : -2.2 0
# x 축
# ```
#
# 실행 결과
#
# ```
# 점의 좌표 x, y를 입력하시오 : 0 0
# 원점
# ```

# %% [markdown]
# ## 3.9 하나의 정수를 입력받아서 이 정수가 2로 나누어지는지, 3으로 나누어지는지, 혹은 두 정수 모두로도 나누어지는지 알려주는 프로그램을 다음과 같이 작성하시오.
# ---
# 실행 결과
#
#
# ```
# 정수를 입력하시오 : 15
# 15는(은) 2(으)로 나누어지지 않습니다.
# 15는(은) 3(으)로 나누어집니다.
# 15는(은) 2와(과) 3 모두로 나누어지지 않습니다.
# ```
#
# 실행 결과
#
#
# ```
# 정수를 입력하시오 : 12
# 12는(은) 2(으)로 나누어집니다.
# 12는(은) 3(으)로 나누어집니다.
# 15는(은) 2와(과) 3 모두로 나누어집니다.
# ```

# %% [markdown]
# ## 2.22 사용자로부터 두 개의 정수 a와 b를 입력받은 다음 a를 b로 나눈 몫과 나머지를 다음과 같이 출력하시오.
# ---
# ```
# a: 202
# b: 50
# a를 b로 나눈 몫: 4
# a를 b로 나눈 나머지: 2
# ```

# %% [markdown]
# ## 3.4 다음과 같이 사용자로부터 나이를 입력받아 20살 이상이면 “Adult", 10살 이상 20살 미 만이면 "Youth", 10살 미만이면 "Kid"를 출력하는 프로그램을 작성하시오.
#
# 실행 결과
#
#
# ```
# 나이를 입력하시오 : 23
# Adult
# ```
# 실행 결과
#
#
# ```
# 나이를 입력하시오 : 18
# Youth
# ```
# 실행 결과
#
#
# ```
# 나이를 입력하시오 : 9
# Kid
# ```

# %% [markdown]
# ## 3.10 사용자로부터 2개의 정수를 a, b를 입력으로 받은 다음 a가 b의 배수인지 아닌지를 판단하여 출력하는 다음과 같은 프로그램을 작성하시오.
# ---
# 실행 결과
#
#
# ```
# 두 정수를 입력하시오 : 15 5
# 15는(은) 5의 배수입니다.
# ```
# 실행 결과
#
#
# ```
# 두 정수를 입력하시오 : 125 52
# 125는(은) 52의 배수가 아닙니다.
# ```

# %% [markdown]
# ## 3.11 1에서 10사이의 복권번호 중에서 3개의 숫자를 모두 맞히면 ‘1억원’, 2개를 맞히면 ‘1 천만원’, 1개를 맞히면 ‘1만원’, 모두 틀리면 ‘다음 기회에...’을 출력하는 복권 시스템이 있다 고 가정하자. 사용자로부터 3개의 정수를 받은 다음 상금을 알려주는 프로그램을 다음과 같이 작성하시오.(단, 이번 회차 복권 당첨 번호가 2, 3, 9라고 가정하자)
# ---
# 실행 결과
#
#
# ```
# 세 복권번호를 입력하시오 : 1 5 7
# 다음 기회에...
# ```
#
# 실행 결과
#
#
# ```
# 세 복권번호를 입력하시오 : 1 2 7
# 상금 1만원
# ```
# 실행 결과
#
#
# ```
# 세 복권번호를 입력하시오 : 1 2 9
# 상금 1천만원
# ```
# 실행 결과 # 1억원이 아님.
#
#
# ```
# 세 복권번호를 입력하시오 : 2 2 2
# 상금 1만원
# ```

# %% [markdown]
# # **실습 문제**

# %% [markdown]
# ## 1. 여러 개의 정수를 입력받아 최솟값과 최댓값을 구하고, 그 사이 범위(최솟값 이상 최댓값 이하)에 있는 모든 정수의 합을 아래와 같이 출력하는 프로그램을 작성하시오.
#
# - 정수는 쉼표로 구분하여 입력받을 것.
# ---
# 실행 결과
# ```
# 정수 여러 개: 19, 5, 23, 77, 41
# 5 이상 77 이하 정수들의 합: 2993
# ```

# %% [markdown]
# ### 1.1 여러 개의 정수를 입력받아 최솟값과 최댓값을 구하고, 그 사이 범위(최솟값 **초과** 최댓값 **미만**)에 있는 모든 정수의 합을 아래와 같이 출력하는 프로그램을 작성하시오.
#
# - 정수는 쉼표로 구분하여 입력받을 것.
# ---
# 실행 결과
# ```
# 정수 여러 개: 19, 5, 23, 77, 41
# 5 초과 77 미만 정수들의 합: 2911
# ```

# %% [markdown]
# ### 1.2 여러 개의 정수를 입력받아 최솟값과 최댓값을 구하고, 그 사이 범위(최솟값 **초과** 최댓값 **미만**)에 있는 정수 중 사용자가 입력한 값을 제외한 수의 합을 아래와 같이 출력하는 프로그램을 작성하시오.
#
# - 정수는 쉼표로 구분하여 입력받을 것.
# ---
# 실행 결과
# ```
# 정수 여러 개: 19, 5, 23, 77, 41
# 5 초과 77 미만 정수들의 합(사용자 입력 값 제외): 2828
# ```

# %% [markdown]
# ##2. cm 단위로 표현된 키를 입력 받아 **피트와 인치의 조합**으로 표현하는 프로그램을 작성하시오.
#
#
# *   1피트는 12인치이고, 1인치는 2.54cm이다.
# ---
# 실행 결과
# ```
# 키: 117.8
# 117.80cm는 3.00피트 10.38인치입니다.
# ```
# 실행 결과
# ```
# 키: 138.2
# 138.20cm는 4.00피트 6.41인치입니다.
# ```

# %% [markdown]
# ## 3. 대화형 모드에서 `dir(str)`를 입력하여, 문자열(`str`)의 메소드를 확인하시오.  `is`로 시작하는 아래 메소드를 조사하시오.
#
#   ---
#   - `isalpha()`
#   - `isalnum()`
#   ---
#   - `isdecimal()`
#   - `isdigit()`
#   - `isnumeric()`
#
#   ---
#   - `islower()`
#   - `isupper()`
#   ---
#   - `isspace()`

# %% [markdown]
# ##4. 사용자로부터 문장을 입력받아 아래 프로그램을 작성하시오.

# %% [markdown]
# ###1. 사용자 입력에서 **숫자만 모은 리스트** 출력
#
#
# ---
# 실행 결과
# ```
# 문장: H4ppy N3w         Y34r
# 문장에 포함된 숫자: ['4', '3', '3', '4']
# ```

# %% [markdown]
# ### 2. 사용자 입력 중 **숫자들의 총합**
# ---
#
# 실행 결과
# ```
# 문장: H4ppy N3w         Y34r
# 문장에 포함된 숫자: ['4', '3', '3', '4']
# 문장에 포함된 숫자 총합: 14
# ```

# %% [markdown]
# ### 3. 사용자 입력에 포함된 **공백**과 그 개수
# ---
#
# 실행 결과
# ```
# 문장: H4ppy N3w         Y34r
# 문장에 포함된 공백: [' ', '\t', '\t']
# 문장에 포함된 공백 개수: 3
# ```

# %% [markdown]
# ### 4. 사용자 입력에 포함된 **모음**과 그 개수
# ---
#
# 실행 결과
# ```
# 문장: H4ppy N3w         Y34r
# 문장에 포함된 모음: []
# 문장에 포함된 모음 개수: 0
# ```

# %% [markdown]
# ### 5. 사용자 입력에 포함된 **소문자**와 그 개수
# ---
#
# 실행 결과
# ```
# 문장: H4ppy N3w         Y34r
# 문장에 포함된 소문자: ['p', 'p', 'y', 'w', 'r']
# 문장에 포함된 소문자 개수: 5
# ```

# %% [markdown]
# ## 5. 사용자로부터 양의 정수를 입력받아 백의 자리 숫자를 출력하는 프로그램을 작성하시오.
#  - 단, 사용자가 양의 정수를 입력하지 않은 경우 오류 메시지를 출력할 것.
#
#  ---
#  실행 결과
#  ```
# 양의 정수: 7598
# 백의 자리 숫자: 5
#  ```
#
#
#  실행 결과
#  ```
# 양의 정수: -7
# 양의 정수를 입력해주세요.
#  ```

# %% [markdown]
# ### 5.1 사용자로부터 양의 정수와 확인할 자리를 입력받아 해당 자리 숫자를 출력하는 프로그램을 작성하시오.
#  - 단, 사용자가 양의 정수를 입력하지 않은 경우 오류 메시지를 출력할 것.
#
#  ---
#  실행 결과
#  ```
# 양의 정수: 57324
# 확인할 자리:1000
# 1000의 자리수: 7
#  ```
