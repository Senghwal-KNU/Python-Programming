# %% [markdown]
# ##  1. 사용자로부터 휴대 전화 번호를 입력받아 아래와 같이  출력하는 프로그램을 작성하시오.
#  - 사용자 입력 양 끝의 공백은 제거할 것.
#  - 사용자 입력에 숫자가 아닌 문자가 있다면 다시 입력받을 것.
#  - 번호가 010으로 시작하지 않는다면 다시 입력받을 것.
#  - 입력된 전화번호가 10자리 혹은 11자리가 아닌 경우 다시 입력받을 것.
#  - 입력 값 출력 시,  전화번호 끝자리는 4자리라고 간주한다.
#  - 해당하는 오류 메시지를 모두 출력할 것.
#
#  ---
#  실행 결과
#  ```
# 휴대전화번호:    010-1234-5678
# [입력오류] 전화번호는 10자리 혹은 11자리로 구성되야 합니다.
# [입력오류] 전화번호는 숫자로만 입력해주세요.
# 휴대전화번호: 0531234567
# [입력오류] 전화번호는 010으로 시작해야 합니다.
# 휴대전화번호:    010123456
# [입력오류] 전화번호는 10자리 혹은 11자리로 구성되야 합니다.
# 휴대전화번호:   0101234567
# 입력하신 번호는 010-123-4567입니다.
# ```

# %% [markdown]
# ## 2.  파일명을 매개변수로 받아  파이썬 소스 파일인지 판단하고 그 결과를 참/거짓으로 반환하는 함수 `ispy()` 함수를 작성하고, 사용자가 입력한 파일명을 전달하여 결과를 아래와 같이 출력하는 프로그램을 작성하시오.
#   - 확장자가 py일 경우 파이썬 소스로 판단한다.
#
# ---
# 실행 결과
#
# ```
# 파일명:    hw07.py
# 파이썬 소스 파일 입니다.
# ```
#
# 실행 결과
#
# ```
# 파일명:  hw07.c
# 파이썬 소스 파일이 아닙니다.
# ```

# %% [markdown]
# ## 11.10 `num1`, `num2`, `div1`, `div2` 를 매개변수로 받아 `num1` 이상 `num2` 이하의 정수 중 `div1`와  `div2`의 공배수를 리스트에 담아 반환하는 함수 `common_mul_lst()`를 작성하시오. 아래 예시와 같이 정수의  범위(단, 입력 순서에 상관없이 작은 수부터 큰 수까지의 범위로 처리)와 공배수를 구할 두 수 `x`, `y`를 입력받아, 함수를 호출한 뒤, 반환된 공배수를 `,`로 구분하여 출력하는 프로그램을 작성하시오.
#
#
# - 리스트 축약으로 작성할 것.
#
#
# ---
# 실행 결과
# ```
# 정수 1: 120
# 정수 2: 190
# 120 이상 190 이하의 수에서 x, y의 공배수를 구합니다. x, y를 입력해주세요.
# x: 4
# y: 6
# 공배수: 120, 132, 144, 156, 168, 180
# ```
#
#
#
# 실행 결과
# ```
# 정수 1: 200
# 정수 2: 50
# 50 이상 200 이하의 수에서 x, y의 공배수를 구합니다. x, y를 입력해주세요.
# x: 4
# y: 7
# 공배수: 56, 84, 112, 140, 168, 196
# ```

# %% [markdown]
# ## 11.12 ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday']로 이루어진 리스트로 부터 다음과 같은 리스트를 생성하시오.
#
# - 리스트 축약으로 작성할 것.
# ---
# 실행 결과
# ```
# ['SUN', 'MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT']
# ```

# %% [markdown]
# ## 5.21 주민등록번호의 앞 6자리 생년월일은 두 자리의 년도, 두 자리의 월, 두 자리의 날짜로 표현된다. 예를 들어 921030은 1992년 10월 30일을 의미한다. 이렇게 주민등록 번호 형식의 생년월일이 입력될 때 "1992년 10월 30일"과 같은 형태로 날짜를 출력하는 코드를 작성하라. 입력되는 날짜의 연도는 1950년 이후부터 입력된다. 즉, 511010은 1951년 10월 10일이지만, 491010은 2049년 10월 10일로 판단해야 한다.
#
#  - 단, 주민등록번호 입력 시 숫자 외의 값이 있다면 오류 메시지를 출력하고 다시 입력받을 것.
#
# ---
# 실행 결과
# ```
# 주민등록번호 첫 6숫자 형식 입력: 57.03.12
# [입력 오류] 숫자로만 입력해주세요.
# 주민등록번호 첫 6숫자 형식 입력: 57/03/12
# [입력 오류] 숫자로만 입력해주세요.
# 주민등록번호 첫 6숫자 형식 입력: 570312
# 1957년 3월 12일
# ```
#
#
# 실행 결과
# ```
# 주민등록번호 첫 6숫자 형식 입력: 011123
# 2001년 11월 23일
# ```

# %% [markdown]
# #**추가 문제**
#
# 아래 과제는 내일 시험에는 포함되지 않습니다.
#
#
# 중간 고사에는 포함되니, 여유가 있으신 분은 미리 풀어보세요.

# %% [markdown]
# # **반복문**

# %% [markdown]
# ## 6.7 `lst`라는 리스트에 `[10, 20, 30, 50, 60]`과 같은 5개의 원소가 있다. 내장 함수 `sum()`를 사용하지 않고 `lst`의 5개 원소의 합을 구하는 프로그램을 작성하여라.
# ---
# 실행 결과
# ```
# 리스트의 원소들의 합 : 170
# ```

# %% [markdown]
# ## 6.9  `lst=[10, 20, 30, 50, 60]` 에서 가장 큰 값을 구하는 프로그램을 `max()` 함수를 사용하지 말고 구현하여라.
# ---
# 실행 결과
# ```
# 리스트의 원소들 중 최댓값 : 60
# ```

# %% [markdown]
# ## 6.12 사용자로부터 $n$을 입력받은 후, $n$개의 정수를 입력받도록 하시오. 그리고 다음과 같이 $n$개의 입력된 값들의 합, 평균, 최댓값, 최솟값을 출력하는 프로그램을 작성하시오.
#   -  `sum()`, `min()`, `max()` 사용 가능
#  - 단, 아래 예시와 같이 $n$개의 정수들이 입력되지 않은 경우 재입력 받을 것: 입력받은 $n$은 양의 정수로 간주한다.
#
# ---
# 실행 결과
# ```
# n: 6
# 6개의 수: 1 2
# [입력 오류] 6개의 수를 입력해주세요.
# 6개의 수: 45 67 20 34 2 100
# 합 : 268
# 평균 : 44.66666666664
# 최댓값: 100
# 최솟값: 2
# ```

# %% [markdown]
# ## 6.13 사용자로부터 정수들을 입력받은 후 입력된 값들의 평균(mean)과 표준편차(standard deviation: $\sigma$로 표기함)를 구하시오. 입력된 값들을 라고 할 때, 표준 편차($\sigma$)를 구하는 식은 다음과 같다.
# $\sigma = \sqrt{\frac{\Sigma_{i=1}^{n}{(x_i-mean)^2}}{n}}$
#
# ---
# 실행 결과
#
# ```
# 정수들: 45 67 20 34 2 100 23 45 67 89
# 합 : 492
# 평균 : 49.2
# 표준편차: 29.71800800861323
# ```

# %% [markdown]
# # **list slicing**

# %% [markdown]
# ## 5.23 한 사람의 정보가 이름, 나이, 성별, 키, 몸무게의 5개 항목 형식으로 저장되어 있다고 하자. 홍길동이라는 사람이 20세에 남자이면서 180cm 키에 100kg의 몸무게라면 `['홍길동', 20, 1, 180.0, 100.0]`와 같이 리스트로 표현할 수 있다. 두 번째 사람이 자스민이라는 22세의 여성으로 162cm의 키에 60kg의 몸무게라고 하면 `['자스민', 22, 0, 162.0, 60.0]`으로 표현할 수 있다. 남녀 성별은 여자는 0, 남자는 1로 표현한 것이다. 두 사람의 정보를 모두 모으면, `['홍길동', 20, 1, 180.0, 100.0, '자스민', 22, 0, 162.0, 60.0]`와 같이 표현할 수 있고, 이렇게 여러 명의 정보를 담을 수 있다.

# %% [markdown]
# ### (1) 어떤 리스트에 다음과 같은 사람들이 있으며 이 정보를 바탕으로 만든 `person_list`가 있을 때, 몇 명의 정보가 `person_list`에 담겼는지를 출력하는 함수를 작성해 보라. 이를 위하여 `how_many_persons()` 함수를 작성하여라.
# ```
# person1 = ['온달', 20, 1, 180.0, 100.0]
# person2 = ['이사부', 25, 1, 170.0, 70.0]
# person3 = ['평강', 22, 0, 169.0, 60.0]
# person4 = ['혁거세', 40, 1, 150.0, 50.0]
#
# person_list = person1 + person2 + person3 + person4
#
# n_persons = how_many_persons(person_list)  # 여러분이 작성할 함수입니다
# #아래와 같이 인원수 출력
# ```
# ---------
# 실행결과
#
# ```
# 4명의 정보가 담겨 있습니다.
# ```

# %% [markdown]
# ### (2) 이 문제에서 저장하는 방식으로 사람들의 정보를 담은 어떤 리스트에 담긴 사람들의 평균 나이를 계산하는 프로그램을 슬라이싱을 이용하여 구현해 보라.
#
# ```
# person_list = person1 + person2 + person3 + person4
#
# average_age = compute_average_age(person_list)
# #아래 예시와 같이 average_age 출력
#
# ```
# ---------
# 실행결과
#
# ```
# 평균 나이는 26.75세입니다.
# ```

# %% [markdown]
# ### (3) 주어진 리스트에 저장된 사람들의 성별을 분석하여 남자의 수와 여자의 수를 출력하라.
#
# ```
# person_list = person1 + person2 + person3 + person4
#
# #코드 작성 = count_males_females(person_list)
# #아래 양식과 같이 남녀 수 출력
#
# ```
# ---------
# 실행결과
#
# ```
# 리스트에는 남자가 3명, 여자가 1명입니다.
# ```

# %% [markdown]
# ### (4) 주어진 리스트에 포함된 정보를 각각의 사람별로 다음과 같이 출력해 보라.
#
# ```
# person_list = person1 + person2 + person3 + person4
# display_persons(person_list) # 여러분이 작성할 함수입니다
#
# ```
# ---------
#
# 실행결과
# ```
# ['온달', 20, 1, 180.0, 100.0]
# ['이사부', 25, 1, 170.0, 70.0]
# ['평강', 22, 0, 169.0, 60.0]
# ['혁거세', 40, 1, 150.0, 50.0]
# ```
