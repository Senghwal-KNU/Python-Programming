# %% [markdown]
# #**scores.csv**
# *scores.csv* 파일 내용을 확인한 뒤, 아래 프로그램을 작성하시오.
#
# 파일 다운로드: https://drive.google.com/file/d/10YNyD3MifHzE4He6z3lvtMeKyyfaW04V/view?usp=sharing

# %% [markdown]
# ## 1. 파일에서 내용을 읽어와 학생별 점수를 저장하는 딕셔너리를 작성하고, *score_dct.txt* 파일에 출력하시오.
#
#  - 학생별 점수는 정수를 원소로 가지는 `tuple`로 표현할 것.
#  - 파일에 출력 완료 후, 폴더내 *score_dct.txt* 파일을 확인하라는 메시지를 출력할 것.
#  - *hint.* 파일명은 파일 객체의 `name` 속성에 저장됨.
#  - (선택) 여유가 있다면, 이 외에 파일의 속성을 `dir()`로 확인해보세요.
# ---
# 콘솔 실행 결과
# ```
# 폴더 내 score_dct.txt 파일을 확인해주세요.
# ```
#
# *score_dct.txt* 파일 결과
#  ```
# 뽀로로: (9, 10, 8, 10)
# 크롱: (8, 7, 10, 5)
# 둘리: (5, 3, 9, 4)
# 고길동: (4, 10, 9, 7)
# 루피: (5, 0, 4, 0)
# 에디: (5, 6, 1, 2)
# 포비: (6, 3, 9, 6)
# 해리: (10, 4, 6, 10)
# 또치: (9, 2, 10, 5)
# 희동: (7, 1, 6, 0)
# ```

# %% [markdown]
# ## 2. 학생의 이름을 입력받아, 해당 학생의 성적을 출력하시오.
#  - 단, 해당 학생이 존재하지 않을 경우, 이를 알릴 것.
# ---
# 실행 예시
# ```
# 이름: 희동
# 희동 학생의 성적은 (7, 1, 6, 0) 입니다.
# ```
#
#
#
# 실행 예시
# ```
# 이름: 희동이
# 희동이 학생은 존재하지 않습니다.
# ```

# %% [markdown]
# ## 2. 총점을 입력받아, 해당 총점과 일치하는 학생을 출력하시오.
#  - 해당 총점의 학생이 여러 명인 경우 쉼표로 구분하여 출력할 것.
#  - 해당 총점의 학생이 없는 경우 이를 알릴 것.
#  - 총점을 정수로 입력하지 않은 경우, 발생하는 예외를 처리하고 올바른 값이 입력될 때까지 반복할 것.
#
#
# **Remark**
#
# 우리 수업에서 다루는 수준의 예외는 (데이터가 제대로 들어온다는 가정하에) 핵심 로직 먼저 구현 후 처리합니다.
#
# ---
# 실행 예시
# ```
# 총점: 30
# 총점이 30인 학생: 크롱, 고길동, 해리
# ```
#
# 실행 예시
# ```
# 총점: 20
# 총점이 20인 학생은 존재하지 않습니다.
# ```
#
#
# 실행 예시
# ```
# 총점: 만점
# [입력오류] 점수는 정수로 입력해주세요.
# 총점: 37.4
# [입력오류] 점수는 정수로 입력해주세요.
# 총점: 37
# 총점이 37인 학생: 뽀로로
# ```

# %% [markdown]
# ## 3. 위 딕셔너리에서 파이썬 성적만 추출하여 출력하시오.
#
# ---
# 실행 결과
# ```
# 파이썬 성적: (10, 7, 3, 10, 0, 6, 3, 4, 2, 1)
# ```

# %% [markdown]
# # **Student class**
#
#  아래 조건에 따라 클래스를 완성하시오.

# %% [markdown]
# ## 1. 아래 테스트 코드와 실행 결과를  확인한 뒤, 학생과 성적을 저장하는 `Student` 클래스를 구현하시오.
#
#
# 멤버 변수: private
#
#  - 이름
#  - 파이썬 성적
#  - c++ 성적
#
# 메소드
#  - 필요에 따라 적절히 구현하시오.
#
#
#
#
# ---
# 테스트 코드
# ```
# pororo = Student('뽀로로', 10, 10)
# print(pororo)
# ```
#
#
# 실행 결과
# ```
# 파이썬 10점, C++ 10점인 뽀로로 학생입니다.
# ```

# %% [markdown]
# ## 2. 다운받은 *scores.csv* 파일에서 데이터를 읽어와 학생 객체들의 리스트 `lst`를 생성하시오. 아래 코드와 실행 결과를  확인한 뒤, `Student` 클래스에 필요한 내용을 추가 구현하시오.
#
# ---
# 테스트 코드
# ```
# print(lst)
# ```
#
#
# 실행 결과
# ```
# [<뽀로로 - 파이썬: 10점, C++: 10점>, <크롱 - 파이썬: 7점, C++: 5점>, <둘리 - 파이썬: 3점, C++: 4점>, <고길동 - 파이썬: 10점, C++: 7점>, <루피 - 파이썬: 0점, C++: 0점>, <에디 - 파이썬: 6점, C++: 2점>, <포비 - 파이썬: 3점, C++: 6점>, <해리 - 파이썬: 4점, C++: 10점>, <또치 - 파이썬: 2점, C++: 5점>, <희동 - 파이썬: 1점, C++: 0점>]
# ```

# %% [markdown]
# ## 2. 아래 코드와 실행 결과를 확인한 뒤, `Student` 클래스에 필요한 내용을 추가 구현하시오.
#
# ---
# 테스트 코드
# ```
# print(f'{       }의 총점 >= {       }의 총점:', lst[0]>=lst[1]) #중괄호 안 빈 곳을 적절히 완성할 것.
#
# print('총점 순 내림차순 정렬:', sorted(lst, reverse = True))
# highest = max(lst)
# print(f'최고득점자: {       }(총점 {       }점)') #중괄호 안 빈 곳을 적절히 완성할 것.
# ```
#
#
# 실행 결과
# ```
# 뽀로로의 총점 >= 크롱의 총점: True
# 총점 순 내림차순 정렬: [<뽀로로 - 파이썬: 10점, C++: 10점>, <고길동 - 파이썬: 10점, C++: 7점>, <해리 - 파이썬: 4점, C++: 10점>, <크롱 - 파이썬: 7점, C++: 5점>, <포비 - 파이썬: 3점, C++: 6점>, <에디 - 파이썬: 6점, C++: 2점>, <둘리 - 파이썬: 3점, C++: 4점>, <또치 - 파이썬: 2점, C++: 5점>, <희동 - 파이썬: 1점, C++: 0점>, <루피 - 파이썬: 0점, C++: 0점>]
# 최고득점자: 뽀로로(총점 20점)
# ```

# %% [markdown]
# # **딕셔너리 축약 연습**

# %% [markdown]
# ## 10.14 다음과 같이 키:값의 항목을 가지는 fruits 딕셔너리를 '키=값' 형식으로 된 문자열의 리스트로 재구성하여라.
# ---
#
# ```
# fruits = {'Apple': '사과', 'Strawberry': '딸기', 'Peach': '복숭아', 'Grape': '포도'}
# ```
#
# ---
# 실행 결과
# ```
# ['Apple=사과', 'Strawberry=딸기', 'Peach=복숭아', 'Grape=포도']
# ```

# %% [markdown]
# ## 10.15 문제 10.14의 결과로 나타난 다음과 같은 fruits_list 리스트를 이용하여 실행 결과와 같이 원래의 fruits 딕셔너리로 만드시오.
#
# ---
# 실행 결과
# ```
# fruits_list = ['Apple=사과', 'Strawberry=딸기', 'Peach=복숭아', 'Grape=포도']
# fruits = {'Apple': '사과', 'Strawberry': '딸기', 'Peach': '복숭아', 'Grape': '포도'}
# ```
