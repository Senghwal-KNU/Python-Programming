# %% [markdown]
# #**list 순회**

# %% [markdown]
# ## 6.5_1 다음과 같은 리스트 `lst2`에 대해 아래 문장을 출력하시오.
# ---
#
# ```
# lst2 = ['pancake.', 'kiwi juice.', 'espresso.']
# ```
# 실행 결과
#
# ```
# I like pancake.
# I like kiwi juice.
# I like espresso.
# ```

# %% [markdown]
# ## 6.5 다음과 같은 문자열을 가진 두 개의 리스트 `lst1`, `lst2`가 있을 경우 `lst1`과 `lst2`의 조합을 이용하여 다음과 같이 출력하시오.
# ---
#
# ```
# lst1 = ['I like', 'I love']
# lst2 = ['pancake.', 'kiwi juice.', 'espresso.']
# ```
# 실행 결과
#
# ```
# I like pancake.
# I like kiwi juice.
# I like espresso.
# I love pancake.
# I love kiwi juice.
# I love espresso.
# ```

# %% [markdown]
# ## 6.3 다음과 같은 list1, list2가 있을 경우 list1과 list2의 각 원소의 곱셈을 다음과 같이 출력하시오.
# ---
#
# ```
# list1 = [3, 5, 7]
# list2 = [2, 3, 4, 5, 6]
# ```
# 실행 결과
# ```
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# ```

# %% [markdown]
# ## 6.8 `lst` 라는 리스트에 `[10, 20, 30, 50, 60]`과 같은 5개의 원소가 있다. 모든 성분의 곱을 출력하시오.
# ---
# 실행 결과
# ```
# 리스트의 원소들의 곱 : 18000000
# ```

# %% [markdown]
# # **range() 순회**

# %% [markdown]
# ##1. 반복문을 사용하여 아래 내용을 작성하시오.
#
# 1.   'Hello, Python!'을 5번 출력
#   ```
# Hello, Python!
# Hello, Python!
# Hello, Python!
# Hello, Python!
# Hello, Python!
# ```
#
#
# 2.   0에서 4까지의 정수 출력
# ```
# 0
# 1
# 2
# 3
# 4
# ```
#
#
#
# 3.   1이상 100이하의 정수 출력
#
# 4.   1이상 100이하의 짝수 출력
#
# 5.   1이상 100이하의 홀수 출력
#
# 6.   100, 98, 96, …, 0 출력
#
# 7.   -100 이상의 음수 출력

# %% [markdown]
# ##2. for문을 사용하여 아래 프로그램을 작성하시오.
#
#
#
# 1.   1이상 10 이하의 정수의 합 출력
# 2.   1이상 100 이하의 짝수의 합 출력
# ```
# 1 이상 10 이하의 정수의 합: 55
# 1 이상 100 이하의 짝수의 합: 2550
# ```
#
# 3.   사용자로부터 정수 n을 입력받아 1부터 n까지의 정수의 합과 n!을 출력
# ```
# n: 5
# 1이상 5이하의 정수의 합: 15
# 5!: 120
# ```

# %% [markdown]
# ## 3. 구구단을 아래와 같이 출력하시오.

# %% [markdown]
# ###3.1 사용자로부터 2 이상 9 이하의 정수를 입력받아 구구단 해당 단을 출력하시오.
#
#  - 단이 2 이상 9 이하가 아닌 경우, 오류 메시지를 출력하고 반복하여 입력받을 것.
#
# ---
# 실행 결과
# ```
# 단: -6
# [입력오류] 2 이상 9 이하의 정수를 입력해주세요.
# 단: 16
# [입력오류] 2 이상 9 이하의 정수를 입력해주세요.
# 단: 6
# 6 X 1 =  6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# ```

# %% [markdown]
# ### 3.2. 구구단 2단 부터 9단 까지 아래와 같이 출력하시오.
#
# ---
# 실행 결과
#
# ```
# 2 X 1 =  2      2 X 2 =  4      2 X 3 =  6      2 X 4 =  8      2 X 5 = 10      2 X 6 = 12      2 X 7 = 14      2 X 8 = 16      2 X 9 = 18
# 3 X 1 =  3      3 X 2 =  6      3 X 3 =  9      3 X 4 = 12      3 X 5 = 15      3 X 6 = 18      3 X 7 = 21      3 X 8 = 24      3 X 9 = 27
# 4 X 1 =  4      4 X 2 =  8      4 X 3 = 12      4 X 4 = 16      4 X 5 = 20      4 X 6 = 24      4 X 7 = 28      4 X 8 = 32      4 X 9 = 36
# 5 X 1 =  5      5 X 2 = 10      5 X 3 = 15      5 X 4 = 20      5 X 5 = 25      5 X 6 = 30      5 X 7 = 35      5 X 8 = 40      5 X 9 = 45
# 6 X 1 =  6      6 X 2 = 12      6 X 3 = 18      6 X 4 = 24      6 X 5 = 30      6 X 6 = 36      6 X 7 = 42      6 X 8 = 48      6 X 9 = 54
# 7 X 1 =  7      7 X 2 = 14      7 X 3 = 21      7 X 4 = 28      7 X 5 = 35      7 X 6 = 42      7 X 7 = 49      7 X 8 = 56      7 X 9 = 63
# 8 X 1 =  8      8 X 2 = 16      8 X 3 = 24      8 X 4 = 32      8 X 5 = 40      8 X 6 = 48      8 X 7 = 56      8 X 8 = 64      8 X 9 = 72
# 9 X 1 =  9      9 X 2 = 18      9 X 3 = 27      9 X 4 = 36      9 X 5 = 45      9 X 6 = 54      9 X 7 = 63      9 X 8 = 72      9 X 9 = 81
# ```

# %% [markdown]
# ### 3.3 구구단을 한 열에 한 단씩 출력하시오.
#
# ---
# 실행 결과
#
# ```
# 2 X 1 =  2   3 X 1 =  3   4 X 1 =  4   5 X 1 =  5   6 X 1 =  6   7 X 1 =  7   8 X 1 =  8   9 X 1 =  9
# 2 X 2 =  4   3 X 2 =  6   4 X 2 =  8   5 X 2 = 10   6 X 2 = 12   7 X 2 = 14   8 X 2 = 16   9 X 2 = 18
# 2 X 3 =  6   3 X 3 =  9   4 X 3 = 12   5 X 3 = 15   6 X 3 = 18   7 X 3 = 21   8 X 3 = 24   9 X 3 = 27
# 2 X 4 =  8   3 X 4 = 12   4 X 4 = 16   5 X 4 = 20   6 X 4 = 24   7 X 4 = 28   8 X 4 = 32   9 X 4 = 36
# 2 X 5 = 10   3 X 5 = 15   4 X 5 = 20   5 X 5 = 25   6 X 5 = 30   7 X 5 = 35   8 X 5 = 40   9 X 5 = 45
# 2 X 6 = 12   3 X 6 = 18   4 X 6 = 24   5 X 6 = 30   6 X 6 = 36   7 X 6 = 42   8 X 6 = 48   9 X 6 = 54
# 2 X 7 = 14   3 X 7 = 21   4 X 7 = 28   5 X 7 = 35   6 X 7 = 42   7 X 7 = 49   8 X 7 = 56   9 X 7 = 63
# 2 X 8 = 16   3 X 8 = 24   4 X 8 = 32   5 X 8 = 40   6 X 8 = 48   7 X 8 = 56   8 X 8 = 64   9 X 8 = 72
# 2 X 9 = 18   3 X 9 = 27   4 X 9 = 36   5 X 9 = 45   6 X 9 = 54   7 X 9 = 63   8 X 9 = 72   9 X 9 = 81
# ```

# %% [markdown]
# # **while**

# %% [markdown]
# ##1.     사용자로 부터 '가위', '바위', '보' 중 하나를 입력 받아 입력 받은 값 출력하는 프로그램을 작성하시오.
#
#
# *   단, 사용자가 '가위', '바위', '보'를 입력하지 않은 경우 반복하여 입력받을 것.
#
# ---
# 실행 결과
#
# ```
# 가위, 바위, 보 중 하나를 선택하세요: 묵
# [입력오류] 가위, 바위, 보 중 하나를 선택하세요.
# 가위, 바위, 보 중 하나를 선택하세요: 찌
# [입력오류] 가위, 바위, 보 중 하나를 선택하세요.
# 가위, 바위, 보 중 하나를 선택하세요: 빠
# [입력오류] 가위, 바위, 보 중 하나를 선택하세요.
# 가위, 바위, 보 중 하나를 선택하세요: 바위
# 바위를 선택하셨습니다.
# ```

# %% [markdown]
# ##2. 사용자로부터 양의 정수 n을 입력 받아 1부터 n까지의 합 출력하는 프로그램을 작성하시오.
#
# *   단, 양의 정수가 아닐 경우 반복하여 입력 받을 것.
# ---
# 실행 결과
# ```
# 양의 정수: -10
# [입력오류] 양의 정수를 입력해주세요.
# 양의 정수: 0
# [입력오류] 양의 정수를 입력해주세요.
# 양의 정수: 10
# 1부터 10까지의 합: 55
# ```

# %% [markdown]
# ## 3. 사용자로부터 실수 또는 정수를 반복하여 입력받아, 입력된 수들의 개수와 평균을 출력하시오.
#  - 단, 사용자가 quit(Quit, qUit, ...)을 입력하면 입력을 종료할 것.
#  - 사용자 입력 값 양 끝의 공백은 무시할 것.
# ---
# 실행 예시
# ```
# 수: -5.3
# 수: 9.1
# 수: 10
# 수: 4
# 수:     QuiT
#
# 4개 수들의 평균: 4.45
# ```

# %% [markdown]
# #**소수(prime number) 문제**

# %% [markdown]
# ##1. 사용자로부터 정수 1개를 입력 받아 소수 여부를 출력하는 프로그램을 작성하시오.
#
# ---
#
# 실행 결과
# ```
# 정수: 10
# 소수가 아닙니다.
# ```
# 실행 결과
# ```
# 정수: 13
# 소수입니다.
# ```

# %% [markdown]
# ##2. 사용자로부터 정수 2개를 입력 받아 두 정수 사이에 존재하는 소수와 그 개수를 출력하는 프로그램을 작성하시오.
#
#
# *   실행 결과  2 와 같이 큰 수 부터 입력되더라도 제대로 출력할 것.
#
# ---
#
# 실행 결과 1
# ```
# a: 5
# b: 31
# 5와 31 사이의 소수: 7 11 13 17 19 23 29
# 5와 31 사이의 소수 개수: 7
# ```
# 실행 결과 2
# ```
# a: 25
# b: 10
# 10와 25 사이의 소수: 11 13 17 19 23
# 10와 25 사이의 소수 개수: 5
# ```
