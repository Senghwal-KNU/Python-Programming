# %% [markdown]
# #**반복문 실행 결과 예측**

# %% [markdown]
# ###1.
# ```
# for e in ['a', 1, 2, [3, 4]]:
#     print(e, end = ' ')
# print()
# ```
# ###2.
# ```
# for e in ['a', 1, 2, [3, 4]]:
#     print('e', end = ' ')
# print()
# ```
# ###3.
# ```
# for e in 'hello world':
#     print(e, end = '+')
# print()
# ```
# ###4.
# ```
# m = 10
# for x in 'python test 1, 2, 3!':
#     if x.isdigit()==True:
#         m *= int(x)
# print(m)
# ```
# ### 5.
#
#
#
# ```
# for i in range(3):
#     print('Python ')
# print('is ')
# print('FUN! ')
# ```
#
# ### 6.
#
# ```
# for i in range(3):
#     print('Python ')
#     print('is ')
#     print('FUN! ')
# ```
#
# ### 7.
#
# ```
# for i in range(3):
#     print('Python ')
#     print('is ')
# print('FUN! ')
# ```

# %% [markdown]
# # **실습 문제**

# %% [markdown]
# ## 1. 사용자로부터 양의 짝수 $n$을 입력받아, $n$ 이상의 연속된 짝수 10개를 출력하시오.
#  - 단, 양의 짝수가 입력되지 않은 경우, 오류 메시지를 출력한 뒤 반복하여 입력받을 것.
#  - 10개의 짝수는 공백으로 구분하여 출력한다.
#
# ---
# 실행 예시
# ```
# 양의 짝수: 7
# [입력오류] 양의 짝수를 입력해주세요.
# 양의 짝수: -6
# [입력오류] 양의 짝수를 입력해주세요.
# 양의 짝수: 50
# 50 52 54 56 58 60 62 64 66 68
# ```

# %% [markdown]
# ## 2. 사용자로부터 두 개의 정수 $a$, $b$ 를 입력받아, 두 수를 포함하여 그 사이 모든 정수들의 합을 출력하시오.
#  - 단, 큰 수가 먼저 입력되더라도 정상적으로 출력되어야 함.
# - built-in ft. `sum()` 사용 금지
# ---
# 실행 예시
# ```
# a: 10
# b: 5
# 5 이상 10 이하 수들의 합: 45
# ```
#
#
#
#
# 실행 예시
# ```
# a: 4
# b: 9
# 4 이상 9 이하 수들의 합: 39
# ```

# %% [markdown]
# ##3. 반복문을 사용하여 2의 거듭제곱 수 10개를 출력하는 프로그램을 작성하시오.
#
# ---
# 실행 결과
# ```
# 2 4 8 16 32 64 128 256 512 1024
# ```

# %% [markdown]
# ## 4. 상의와 색상이 아래와 같이 각각의 리스트에 저장되어 있다. 가능한 상의 색상 조합을 아래 예시와 같이 출력하시오.
#
# ```
# tops = ['Shirts', 'Blouses', 'Sweaters', 'T-shirts', 'Hoodies']
# colors = ['Red', 'Blue', 'Yellow']
# ```
# ---

# %% [markdown]
# ### 4.1.
#
# **실행 예시** #색상과 상의 사이에 간격은 띄우지 않아도 됩니다.
# ```
# Red     Shirts
# Red     Blouses
# Red     Sweaters
# Red     T-shirts
# Red     Hoodies
# Blue    Shirts
# Blue    Blouses
# Blue    Sweaters
# Blue    T-shirts
# Blue    Hoodies
# Yellow  Shirts
# Yellow  Blouses
# Yellow  Sweaters
# Yellow  T-shirts
# Yellow  Hoodies
# ```

# %% [markdown]
# ### 4.2
#
#
# **실행 예시** #색상과 상의 사이에 간격은 띄우지 않아도 됩니다.
# ```
# Red     Shirts
# Blue    Shirts
# Yellow  Shirts
# Red     Blouses
# Blue    Blouses
# Yellow  Blouses
# Red     Sweaters
# Blue    Sweaters
# Yellow  Sweaters
# Red     T-shirts
# Blue    T-shirts
# Yellow  T-shirts
# Red     Hoodies
# Blue    Hoodies
# Yellow  Hoodies
# ```

# %% [markdown]
# ##5. 사용자로부터 정수 여러 개를 입력받아, 5의 배수가 아닌 수들의 곱을  출력하시오.
# ---
# 실행 예시
#
# ```
# 정수: 10 4 6 -2 7
# 5의 배수가 아닌 수들의 곱: -336
# ```

# %% [markdown]
# ## 6. 사용자로부터 실수 또는 정수를 반복하여 입력받아, 입력된 수들의 개수와 평균을 출력하시오.
#  - 단, 사용자가 `-1`을 입력하면 입력을 종료할 것.
#
# ---
# 실행 예시
# ```
# 수: -5.3
# 수: 9.1
# 수: 10
# 수: 4
# 수: -1
#
# 4개 수들의 평균: 4.45
# ```

# %% [markdown]
# ## 7. 사용자로부터 양의 정수를 입력받아 약수 개수를 출력하는 프로그램을 작성하시오.
#  - 단, 양의 정수가 아닌 경우 오류 메시지를 출력하고, 재입력받을 것.
#
#  ---
#  실행 예시
#
#  ```
#  정수: 24
# 24의 약수 개수: 8
#  ```

# %% [markdown]
# ### 7.1 사용자가 입력한 양의 정수 $n$의 양의 약수를 모두 출력하시오.
#
# ---
# 실행 예시
#
# ```
# 정수: 9
# 1 3 9
# ```

# %% [markdown]
# ## 4.9 사용자로부터 양의 정수 $n$을 입력받은 후 $1^2+2^2+3^2+...+n^2$을 구하는 프로그램을 작성하시오.
#  - 단, 양의 정수가 입력되지 않은 경우 오류 메시지를 출력하고 재입력받을 것.
#  - built-in ft. 사용 금지
# ---
# 실행 결과
#
#
# ```
# 숫자를 입력하세요 : -5
# [입력오류] 양의 정수를 입력해주세요.
# 숫자를 입력하세요 : 5
# 결과는 55입니다.
# ```
