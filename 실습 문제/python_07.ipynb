# %% [markdown]
# #**문자열 메소드 - `str` method**
#
#  **주의** 원본 문자열은   바꾸지 않고, 항상 결과를  **반환**만 함.
#
#  e.g. `s = 'abc'` 일 때,  `s.upper()`의 결과는 `'ABC'` 이지만, 메소드 호출 후에도 `s`는 여전히 `'abc'`임.

# %% [markdown]
# **1**.   `split()`
#
# **2**.   `is~` 메소드: 문자열 확인 메소드
# -   `isalpha()`
# -   `isdigit()`/`isdecimal()`/`isnumeric()`
# -   `isalnum()`
# -   `islower()`/`isupper()`
# -   그 외
#   - `isascii()`
#   - `isprintable()`
#   - `isspace()`
#
#
# **3**.   `upper()`/`lower()`
#
#
# **4**.   `strip()`/`rstrip()`/`lstrip()`
#
# **5**.    `join()`
#
# **6**.   `replace()`
#
#
#
# **7**.    `count()`
#
#
# **8**.   `find()`
#
# **9**.   `format()`

# %% [markdown]
# ## **`replace()`**

# %% [markdown]
# ### 1. 사용자로부터 입력 받은 문자열이 회문인지 판단하는 프로그램을 작성하시오.
#  - 단, 회문이란 앞에서부터 읽으나, 뒤에서부터 읽으나 똑같은 문장을 의미한다.
#  - 사용자가 quit(Quit, qUit, ...) 을 입력할 때까지 반복하여 판단한다.
#  - 구두점, 공백, 대소문자를 무시하고 판단한다.
#
# ---
#
# 실행 결과
# ```
# 문장: abcd
# 회문이 아닙니다.
# 문장: Mr. Owl ate my metal worm
# 회문입니다.
# 문장: "Do geese see God?"
# 회문입니다.
# 문장:    Quit
# 프로그램을 종료합니다.
# ```
#
# hint-> 숨겨진 셀 확인

# %% [markdown]
# ####
# 구두점과 공백은 모두 제거하자.

# %% [markdown]
# ### 2. 사용자가 입력한 문자열의 머리 글자어(acronym)를 출력하는 프로그램을 작성하시오.
#  - by, in, the, of, for, and 와 같은 단어를 제거할 것.
#
# ---
# 실행 예시
#
# ```
# 문자열: National aeronautics and space administration
# NASA
# ```
#
# 실행 예시
# ```
# 문자열: Federal bureau of investigation
# FBI
# ```
#
# 실행 예시
# ```
# 문자열: Organization of the petroleum exporting countries
# OPEC
# ```

# %% [markdown]
# ### 3. 사용자로부터 오늘의 지출을 입력받아 지출 총액, 회당 평균 지출을 출력하는 프로그램을 작성하시오.
#
# -  오늘의 지출은 아래 예시와 같이 $n$만원, $n$천원, 혹은 숫자로 입력할 수 있고 각 지출은 공백으로 구분한다.
# - 이 때, $n$은 정수이다.
#
# ---
# 실행 예시
#
# ```
# 오늘의 지출: 2만원 8900 145천원 9500
# 총 4회 지출 총액은 183,400원이고, 회당 평균 지출은 45,850.00원입니다.
# ```

# %% [markdown]
# ### 11.16 다음과 같은 문자열 리스트로부터 'No. ' 부분을 제외한 숫자 부분을 정수 리스트로 만드시오.
#
# ---
# 실행 결과
# ```
# test_list = ['No. 224', 'No. 587', 'No. 29', 'No. 37']
# num_list = [224, 587, 29, 37]
# ```

# %% [markdown]
# ### 5.24 임의의 문장들을 입력하면, 이 문장들에 포함된 단어를 모두 추출하여 사전식으로 정렬하여 출력하시오.
#  - 아래 예시와 같이 쉼표와 마침표를 포함한 구두점들은 모두 제거하여 단어들을 추출할 것.
#
#
# ---
# 실행 결과
# ```
# 문장: 임의의?문장을 입력:출력, 이것은!테스트;문장. 가:가나:나:나나:다람쥐 : 마린보이.
#
# 사전식 정렬 후:
# 가, 가나, 나, 나나, 다람쥐, 마린보이, 문장, 문장을, 이것은, 임의의, 입력, 출력, 테스트
# ```

# %% [markdown]
# ##**기타 문자열 메소드**

# %% [markdown]
# ### 1. 트위터 메시지 처리

# %% [markdown]
# ####1.1   일반적으로 부정적인 감정은 긍정적인 것보다 적은 양의 단어를 포함한다고 한다. 트위터 메시지에서 단어 개수를 출력하시오.
#
# 실행  예시
#
#
# ```
# 메시지: Python is very easy and powerful!!!
# 단어 수: 6
# ```

# %% [markdown]
# ####1.2 금지 단어 'foo'의 개수를 출력하시오.
#
# ---
# 실행 예시
# ```
# 메시지: This is a foo situation. Oh foo! I can't believe this foo happened.
# 금지 단어 'foo'의 개수: 3
# ```

# %% [markdown]
# ### 5.26 어떤 문자열이 다음과 같이 주어져 있다고 하자. 그런데, 이 문자열에 나타난 도시 중에서 'Bython' 시는 최근 'Python'시로 이름을 변경하였다. 이를 반영하여 이 문자열에 나타나는 "Bython"의 수를 다음과 같이 출력하라.
#
# ---
# 실행결과
# ```
# 주어진 문자열 :
# Park(Java city), Kim(C city), Kang(Bython city), Lee(Bython city), Hong(Ruby city), Cho(Bython city), Koo(C city), Ryu(C++ city)
#
# Bython이 3번 나옵니다.
# ```

# %% [markdown]
# # **`list` 기본 문제**

# %% [markdown]
# ## LAB 6-1: 리스트의 생성

# %% [markdown]
# ### 1. 1부터 10까지의 숫자 중에서 짝수를 요소로 가지는 리스트를 생성하여라(10을 포함).
# ```
# [2, 4, 6, 8, 10]
# ```

# %% [markdown]
# ### 3. 'Korea', 'China', 'India', 'Nepal' 의 네 원소를 가지는 리스트를 생성하여라.
# ```
# ['Korea', 'China', 'India', 'Nepal']
# ```

# %% [markdown]
# ### 5. 'XYZ' 문자열을 이용하여 'X', 'Y', 'Z'라는 요소를 가지는 리스트를 생성하여라.
# ```
# ['x', 'y', 'z']
# ```

# %% [markdown]
# ## LAB 6-2 : 리스트의 생성과 인덱싱

# %% [markdown]
# ### 4. 'Korea', 'China', 'Russia', 'Malaysia' 원소를 가지는 nations라는 리스트를 생성하여라. 그리고 이 리스트의 가장 첫 원소를 출력하여라.
# ```
# nations의 첫 원소 : Korea
# ```

# %% [markdown]
# ### 5. 4번에서 생성한 nations 리스트의 가장 마지막 원소를 음수 인덱스를 사용하여 출력하여라.
# ```
# nations의 마지막 원소 : Malaysia
# ```

# %% [markdown]
# ## LAB 6-3 : 리스트의 삽입과 삭제, in 연산자

# %% [markdown]
# ### 1.  `lst = [2, 3, 5, 7]`라는 리스트를 생성하시오. 그리고 append() 메소드를 사용하여 11을 추가하시오.
#
# ```
# 추가 후: [2, 3, 5, 7, 11]
# ```

# %% [markdown]
# ### 2. 1번 문제의  리스트에 있는 3이라는 원소를 remove() 메소드를 사용하여 제거하시오.
#
# ```
# 삭제 후: [2, 5, 7, 11]
# ```

# %% [markdown]
# ### 3. 'Korea', 'China', 'Russia', 'Malaysia' 라는 국가이름을 원소로 가지는 nations라는 리스트에 append() 메소드를 사용하여 'Nepal'을 추가하시오. 이 때 추가 전과 추가 후의 결과를 다음과 같이 출력하시오.
#
#
# ```
# 국가 목록 : ['Korea', 'China', 'Russia', 'Malaysia']
# 추가 후 국가 목록 : ['Korea', 'China', 'Russia', 'Malaysia', 'Nepal']
# ```

# %% [markdown]
# ### 4. 3번 문제의 nations라는 리스트에 'Japan'과 'Russia'가 있는지 검사하여 출력하시오. 이때 in 연산자를 사용하여 리스트에 항목이 있는가 검사하고 출력시에는 if-else 조건문을 사용하시오.
#
# ```
# Japan 은(는) 국가 목록에 없습니다.
# Russia 은(는) 국가 목록에 있습니다.
# ```

# %% [markdown]
# ### 5. 3번 문제의 nations라는 리스트에서 사전 순서로 가장 먼저 나오는 나라와 가장 뒤에 나오는 나라를 다음과 같이 출력하시오.
# ```
# 사전에 가장 먼저 나오는 나라 : China
# 사전에 가장 뒤에 나오는 나라 : Russia
# ```

# %% [markdown]
# ## 6.6 다음은 리스트를 이용한 프로그램이다. 빈 칸에 들어갈 알맞은 내용을 적으시오.
# ---
# ```
# >>> list1 = [2, 3, 4, 1, 32]
# >>> max(list1)
# 1)
# >>> sum(list1)
# 2)
# >>> list1.remove(32)
# >>> list1
# 3)

# %% [markdown]
# # **리스트 메소드 - `list` method**

# %% [markdown]
# ## 6.4 `lst = [2, 3, 4, 5, 6]`이 있을 경우, 이 리스트의 순서를 바꾸는 기능을 `reverse()` 메소드를 사용하지 않고  구현하시오.
#  - `pop()`, `append()` 메소드를 사용해서 작성해보세요.
#
# ---
# 실행 결과
# ```
# lst = [2, 3, 4, 5, 6]
# rvs = [6, 5, 4, 3, 2]
# ```

# %% [markdown]
# ## 6.17 다음 조건을 만족하는 프로그램을 작성하라.
#
# ### 1) 'dog', 'cat', 'tiger', 'lion'을원소로 가지는 `animals` 리스트를 만들어라. 그리고 다음과 같이 출력하여라.
# ---
# 실행 결과
# ```
# animals = ['dog', 'cat', 'tiger', 'lion']
# ```
#
# ### 2) ‘I love dog.’, ‘I love cat.’, ‘I love tiger.’, ‘I love lion.’를 출력하는 프로그램을 작성하시오.

# %% [markdown]
# ### 3) 'dog', 'cat', 'tiger', 'lion'을 원소로 가지는 `animals` 리스트의 원소들을 한칸씩 왼쪽으로 이동시키도록 하여라. 이 때 가장 왼쪽의 'dog'는 가장 오른쪽으로 위치하도록 만들어라. 그리고 다음과 같이 출력하여라.
# ---
# 실행 결과
#
# ```
# animals = ['cat', 'tiger', 'lion', 'dog']
# ```

# %% [markdown]
# ### 4) `animals`를 임의의 순서로 섞은 후, 출력하시오.
#
#
# ---
# 실행 예시
# ```
# animals = [ 'cat', 'dog','lion', 'tiger']
# ```

# %% [markdown]
# ## 6.19 `lst = ['abc', 'bcd', 'abc', 'abba', 'cddc', 'opq', 'opq']`와 같은 문자열을 가진 리스트가 존재한다. 이 리스트에서 중복해서 나타나는 `'abc'`와 `'opq'`를 제거한 리스트 `rslt = ['abc', 'bcd', 'abba', 'cddc', 'opq']`를 생성하여라.
# ---
# 실행 결과
# ```
# lst = ['abc', 'bcd', 'abc', 'abba', 'cddc', 'opq', 'opq']
# rslt = ['abc', 'bcd', 'abba', 'cddc', 'opq']
# ```

# %% [markdown]
# ## 1. 사용자로부터 과일 이름을 공백으로 구분하여 여러 개 입력받아 아래 내용을 구현하시오.
#  - 단, 입력된 과일이 없을 경우 오류 메시지를 출력하고 재입력을 요구한다.
#
#  ---
#  실행 예시
#
#  ```
# 과일 여러 개:
# [입력오류] 과일을 입력해주세요.
# 과일 여러 개: 사과 수박 포도 복숭아 귤 포도 사과 포도
# ```

# %% [markdown]
# ###1.1 입력된 과일에 중복이 있으면 제거하여 출력하시오.
#  - 리스트 통째로 출력하지 말고, 아래와 같이 성분을 쉼표로 구분하여 출력할 것.
# ---
# 실행 예시
# ```
# 중복 제거 후 과일: 사과, 수박, 포도, 복숭아, 귤
# ```

# %% [markdown]
# ### 1.2 위 문제에 이어서 작성할 것: 사용자로부터 과일을 반복하여 입력받아, 기존 리스트에 추가하시오.
#  - 단, 사용자는 이미 리스트에 있는 과일은 입력하지 않는다고 가정하자.
#  -  '종료'를 입력한 경우 입력을 중단하고, 과일 추가 결과를 출력한다.
#  - 사용자 입력 양 끝에 공백이 있는 경우, 이를 제거할 것.
#
#
#  ---
#  실행 예시
#  ```
# 과일: 딸기
# 딸기를 추가했습니다.
# 과일:       감
# 감를 추가했습니다.
# 과일:     종료
# 과일 추가 후: 사과, 수박, 포도, 복숭아, 귤, 딸기, 감
# ```

# %% [markdown]
# ##2. 이번에도  과일을 추가하는 기능을 구현하시오. 추가 방법은 다음과 같다.
#
#  - 과일 이름만 입력하면, 해당 리스트에 없는 경우  마지막에 추가한다.
#  - 위치와 과일 이름을 함께 입력하면, 지정한 위치에 추가한다.
#  - 이번에도 사용자가 이미 존재하는 과일은 입력하지 않는다고 가정하자.
#
#  ---
#  실행 예시
#  ```
# 과일 여러 개: 사과 수박
# 중복 제거 후 과일: 사과, 수박
# ------------------------------------
# [과일 추가]
#
# 과일: 포도 귤
# 과일 추가 후: 사과, 수박, 포도, 귤
#
# 과일: 3 복숭아
# 과일 추가 후: 사과, 수박, 복숭아, 포도, 귤 # 3번째에 복숭아 추가
#
# 과일: 1 자두 멜론
# 과일 추가 후: 자두, 멜론, 사과, 수박, 복숭아, 포도, 귤 # 1번째부터 자두 멜론 추가
#
# 과일:       종료
# 과일 추가를 종료합니다.
#  ```

# %% [markdown]
# ## 3. 사용자로부터 양의 정수를 하나씩 반복하여 입력받아, 입력된 수 중 짝수들만 출력하시오.
#  - 단, 사용자가 stop(Stop, sToP, ...)을 입력하면 입력을 종료할 것.
#  - 사용자 입력 값 양 끝의 공백은 무시할 것.
#  - 사용자 입력 값 중 짝수가 없을 경우 이를 알릴 것.
#  - 짝수가 여러 개인 경우 쉼표로 구분하여 출력할 것.
#
#
# ---
# 실행 예시
# ```
# 정수: 5
# 정수: 10
# 정수: 91
# 정수: 43
# 정수: 144
# 정수: stop
# 입력 값 중 짝수들: 10, 144
# ```
#
# 실행 예시
# ```
# 정수: 5
# 정수: stop
# 입력 값 중에는 짝수가 없습니다.
# ```

# %% [markdown]
# ## 4. 사용자로부터 오늘의 지출을 입력받아 지출 총액, 회당 평균 지출을 출력하는 프로그램을 작성하시오.
#
# -  오늘의 지출은 아래 예시와 같이 $n$만원, $n$천원, 혹은 숫자로 입력할 수 있고 각 지출은 공백으로 구분한다.
# - 이 때, $n$은 정수이다.
#
# ---
# 실행 예시
#
# ```
# 오늘의 지출: 2만원 8900 145천원 9500
# 총 4회 지출 총액은 183,400원이고, 회당 평균 지출은 45,850.00원입니다.
# ```

# %% [markdown]
# ###4.1 이번에는 *4.5만원*, *6.7천원* 과 같이  만원과 천원 앞에 실수가 올 수 있는 프로그램을 작성하시오.
#
#
# ---
# 실행 예시
#
# ```
# 오늘의 지출: 2만원 8900 145천원 9500 4.5만원 53700 6.7천원
# 총 7회 지출 총액은 288,800.0원이고, 회당 평균 지출은 41,257.14원입니다.
# ```

# %% [markdown]
# ##5. 사용자가 입력한 문자열의 머리 글자어(acronym)를 출력하는 프로그램을 작성하시오.
#  - by, in, the, of, for, and 와 같은 단어를 제거할 것.
#
# ---
# 실행 예시
#
# ```
# 문자열: National aeronautics and space administration
# NASA
# ```
#
# 실행 예시
# ```
# 문자열: Federal bureau of investigation
# FBI
# ```
#
# 실행 예시
# ```
# 문자열: Organization of the petroleum exporting countries
# OPEC
# ```

# %% [markdown]
# # **메소드 호출**
#
# 아래 문장의 참/거짓을 판단하시오.

# %% [markdown]
#  - `'hello'.remove('l')`의 결과는 `'heo'`이다. (True, False)

# %% [markdown]
#  - `'hello'.remove('l')`는 실행 가능하다. (True, False)

# %% [markdown]
#  - `'hello'.replace('l', '')`의 결과는 `'heo'`이다. (True, False)

# %% [markdown]
#  - `'hello'.append('!')`의 결과는 `'hello!'`이다. (True, False)

# %% [markdown]
#   - 아래 코드의 결과는 `Hello`이다.  (True, False)
#     ```
#     st = 'hello'
#     st.replace('h', 'H')
#     print(st)
#     ```

# %% [markdown]
#   - 아래 코드의 결과는 `['a', 'b', '!', '!']`이다.  (True, False)
#     ```
#     lst = ['a', 'b', 'c', 'c']
#     lst.replace('c', '!')
#     print(lst)
#     ```

# %% [markdown]
#   - 아래 코드의 결과는 `['a', 'b', 'c', 'c', 'abc']`이다.  (True, False)
#     ```
#     lst = ['a', 'b', 'c', 'c']
#     lst = lst.append('abc')
#     print(lst)
#     ```

# %% [markdown]
# ### **문제 풀이시 주의할 점**

# %% [markdown]
# * **자료형별 메소드**
#
#   `str`, `list` 에서 호출할 수  있는 메소드를 구분할 수 있는가.
# *  **문자열의 불변**
#
#    `str`은 메소드를 호출하더라도 원본은 변경되지 않음을 이해하고 있는가.
#
#
# *  **리스트 메소드의 반환값(결과값)**
#
#
#     `list`의 메소드 대부분은 리스트 원본 자체를 변경할 뿐, 함수의 결과값은 없음을 이해하고 있는가.
